# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)

# %%
#read_data

# %%
df=pd.read_csv(r'F:edu_project/Property_Price_Train.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type Lot_Configuration Property_Slope  \
# 0            Reg          Lvl       AllPub                 I             GS
# 1            Reg          Lvl       AllPub              FR2P             GS
# 2            IR1          Lvl       AllPub                 I             GS
# 3            IR1          Lvl       AllPub                 C             GS
# 4            IR1          Lvl       AllPub              FR2P             GS
#
# ...

# %%
df.shape
# Out:
# (1459, 81)

# %%
df.describe()
# Out:
#                 Id  Building_Class   Lot_Extent       Lot_Size  \
# count  1459.000000     1459.000000  1200.000000    1459.000000
# mean    730.000000       56.922550    70.045833   10517.225497
# std     421.321334       42.304033    24.294456    9984.675721
# min       1.000000       20.000000    21.000000    1300.000000
# 25%     365.500000       20.000000    59.000000    7549.000000
# 50%     730.000000       50.000000    69.000000    9477.000000
# 75%    1094.500000       70.000000    80.000000   11603.000000
# max    1459.000000      190.000000   313.000000  215245.000000
#
#        Overall_Material  House_Condition  Construction_Year  Remodel_Year  \
# count       1459.000000      1459.000000        1459.000000   1459.000000
# mean           6.100069         5.575051        1971.272104   1984.879369
# std            1.383171         1.113125          30.212814     20.645927
# min            1.000000         1.000000        1872.000000   1950.000000
# ...

# %%
num_col = []
cat_col = []
for i in df.columns:
    if df[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
print('There are', len(num_col) ,'numerical features in the dataset')
print('There are', len(cat_col), 'categorical features in the dataset')
# Out:
# There are 38 numerical features in the dataset
# There are 43 categorical features in the dataset

# %% [markdown]
# # Null values

# %%
df.isnull().any().sum()
# Out:
# 19

# %%
# 19 colums have missing values

# %%
print('Percentage of Missing Values in each column is as follows:')
print(round(df.isnull().sum()/len(df.index)*100,2).sort_values(ascending=False)[ round(df.isnull().sum()/len(df.index),2) > 0 ] )
# Out:
# Percentage of Missing Values in each column is as follows:
# Pool_Quality             99.52
# Miscellaneous_Feature    96.30
# Lane_Type                93.76
# Fence_Quality            80.74
# Fireplace_Quality        47.22
# Lot_Extent               17.75
# Garage_Condition          5.55
# Garage                    5.55
# Garage_Built_Year         5.55
# Garage_Finish_Year        5.55
# Garage_Quality            5.55
# Exposure_Level            2.60
# BsmtFinType2              2.60
# BsmtFinType1              2.54
# Basement_Condition        2.54
# Basement_Height           2.54
# Brick_Veneer_Area         0.55
# Brick_Veneer_Type         0.55
# dtype: float64

# %%
# Here we can see that,5 features have more than 5% missing values.

# %%
# Checking if NaN Values have any impact on the Sale Price or not
nan_col = []
for i in df.columns:
    if df[i].isnull().sum() > 0:
        nan_col.append(i)
df_copy = df.copy()    
fig,axs= plt.subplots(7,3,figsize=(20,50),squeeze=True)
for i,ax in zip(nan_col,axs.flatten()):    
    df_copy[i] = np.where(df_copy[i].isnull(), 'Null Values', 'Non-Null Values') 
    df_copy.groupby(i)['Sale_Price'].median().plot.bar(color = list('gr'),rot=0,ax=ax,subplots=True)
axs[6,1].set_axis_off()    
axs[6,2].set_axis_off() 
plt.show()

# %% [markdown]
# # Droping Features wich have above 40% missing values

# %%
round(df.isnull().sum()/len(df.index),2)[round(df.isnull().sum()/
                                                                 len(df.index),2).values>0.40]
# Out:
# Lane_Type                0.94
# Fireplace_Quality        0.47
# Pool_Quality             1.00
# Fence_Quality            0.81
# Miscellaneous_Feature    0.96
# dtype: float64

# %%
#df = df.drop(['Lane_Type','Fireplace_Quality','Pool_Quality','Fence_Quality','Lot_Extent','Miscellaneous_Feature','Month_Sold'],axis='columns')

# %%
df = df.drop(['Lane_Type','Fireplace_Quality','Pool_Quality','Fence_Quality','Miscellaneous_Feature'],axis='columns')

# %%
df.shape
# Out:
# (1459, 76)

# %%
#Features with missing values

# %%
round(df.isnull().sum()/len(df.index),2)[round(df.isnull().sum()/
                                                                 len(df.index),2).values>0.00]
# Out:
# Lot_Extent            0.18
# Brick_Veneer_Type     0.01
# Brick_Veneer_Area     0.01
# Basement_Height       0.03
# Basement_Condition    0.03
# Exposure_Level        0.03
# BsmtFinType1          0.03
# BsmtFinType2          0.03
# Garage                0.06
# Garage_Built_Year     0.06
# Garage_Finish_Year    0.06
# Garage_Quality        0.06
# Garage_Condition      0.06
# dtype: float64

# %%
# list of variables that contain year information
year_feature = [feature for feature in num_col if 'Yr' in feature or 'Year' in feature]
df[year_feature].head()
# Out:
#    Construction_Year  Remodel_Year  Garage_Built_Year  Year_Sold
# 0               2003          2003             2003.0       2008
# 1               1976          1976             1976.0       2007
# 2               2001          2002             2001.0       2008
# 3               1915          1970             1998.0       2006
# 4               2000          2000             2000.0       2008

# %%
num_col = []
cat_col = []
for i in df.columns:
    if df[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
print('There are', len(num_col) ,'numerical features in the dataset')
print('There are', len(cat_col), 'categorical features in the dataset')
# Out:
# There are 38 numerical features in the dataset
# There are 38 categorical features in the dataset

# %%
for feature in cat_col:
    print('The feature is {} and number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# The feature is Zoning_Class and number of categories are 5
# The feature is Road_Type and number of categories are 2
# The feature is Property_Shape and number of categories are 4
# The feature is Land_Outline and number of categories are 4
# The feature is Utility_Type and number of categories are 2
# The feature is Lot_Configuration and number of categories are 5
# The feature is Property_Slope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is House_Type and number of categories are 5
# The feature is House_Design and number of categories are 8
# The feature is Roof_Design and number of categories are 6
# The feature is Roof_Quality and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %% [markdown]
# # Discrete+Contineous

# %%
discrete_feature=[feature for feature in num_col if len(df[feature].unique())<26 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
continuous_feature=[feature for feature in num_col if feature not in discrete_feature+year_feature+['Id']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 16

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtypes=='O']
len(categorical_features)
# Out:
# 38

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price

df.groupby('Year_Sold')['Sale_Price'].median().plot()
plt.xlabel('Year_Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5,1,'House Price vs YearSold')

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
#Here we can see, many contineous variables are skwed

# %% [markdown]
# # Outlier_Detection

# %%
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(df[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log

# %%
df.shape
# Out:
# (1459, 76)

# %%
## Temporal Variables (Date Time Variables)

for feature in ['Construction_Year','Remodel_Year','Garage_Built_Year']:
       
    df[feature]=df['Year_Sold']-df[feature]

# %%
df[year_feature].head()
# Out:
#    Construction_Year  Remodel_Year  Garage_Built_Year  Year_Sold
# 0                  5             5                5.0       2008
# 1                 31            31               31.0       2007
# 2                  7             6                7.0       2008
# 3                 91            36                8.0       2006
# 4                  8             8                8.0       2008

# %%
df.shape
# Out:
# (1459, 76)

# %% [markdown]
# # Data_Processing

# %%
# Dropping ID Columns from dataset since it is useless in the prediction usecase
df.drop('Id', axis=1, inplace=True)

# %%
df.shape
# Out:
# (1459, 75)

# %%
#Here I am capturing the features wich have 99% same observations

# %%
# Trying to remove redundant features
def redundant_feature(df):
    redundant = []
    for i in df.columns:
        counts = df[i].value_counts()
        count_max = counts.iloc[0]
        if count_max / len(df) * 100 > 99:
            redundant.append(i)
    redundant = list(redundant)
    return redundant

# %%
redundant_features = redundant_feature(df)
redundant_features
# Out:
# ['Road_Type', 'Utility_Type', 'Pool_Area']

# %%
df.drop(redundant_features,axis=1,inplace=True)

# %%
df.shape
# Out:
# (1459, 72)

# %%
df[['Building_Class','Month_Sold','Year_Sold']].head(4)
# Out:
#    Building_Class  Month_Sold  Year_Sold
# 0              60           2       2008
# 1              20           5       2007
# 2              60           9       2008
# 3              70           2       2006

# %%
# Converting Building_Class,Month_Sold,Year_Sold to String since they are categorical features and should not be treated as numerical features
df[['Building_Class']] = df[['Building_Class']].astype(str)

# %%
df[['Month_Sold']] = df[['Month_Sold']].astype(str)

# %%
df[['Year_Sold']] = df[['Year_Sold']].astype(str)

# %%
# Checking the number of numerical features and the number of categorical features
num_col = []
cat_col = []
for i in df.columns:
    if df[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
print('There are', len(num_col) ,'numerical features in the dataset')
print('There are', len(cat_col), 'categorical features in the dataset')
# Out:
# There are 33 numerical features in the dataset
# There are 39 categorical features in the dataset

# %%
df.shape
# Out:
# (1459, 72)

# %%
df.head(3)
# Out:
#   Building_Class Zoning_Class  Lot_Extent  Lot_Size Property_Shape  \
# 0             60          RLD        65.0      8450            Reg
# 1             20          RLD        80.0      9600            Reg
# 2             60          RLD        68.0     11250            IR1
#
#   Land_Outline Lot_Configuration Property_Slope Neighborhood Condition1  \
# 0          Lvl                 I             GS      CollgCr       Norm
# 1          Lvl              FR2P             GS      Veenker      Feedr
# 2          Lvl                 I             GS      CollgCr       Norm
#
#   Condition2 House_Type House_Design  Overall_Material  House_Condition  \
# 0       Norm       1Fam       2Story                 7                5
# 1       Norm       1Fam       1Story                 6                8
# 2       Norm       1Fam       2Story                 7                5
#
#    Construction_Year  Remodel_Year Roof_Design Roof_Quality Exterior1st  \
# ...

# %% [markdown]
# # Filling the Missing values

# %%
for e in cat_col:
    df[e]=df[e].fillna(df[e].mode()[0])

# %%
for e in num_col:
    df[e]=df[e].fillna(df[e].median())

# %%
df.isnull().sum()
# Out:
# Building_Class               0
# Zoning_Class                 0
# Lot_Extent                   0
# Lot_Size                     0
# Property_Shape               0
# Land_Outline                 0
# Lot_Configuration            0
# Property_Slope               0
# Neighborhood                 0
# Condition1                   0
# Condition2                   0
# House_Type                   0
# House_Design                 0
# Overall_Material             0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# Roof_Design                  0
# Roof_Quality                 0
# Exterior1st                  0
# Exterior2nd                  0
# Brick_Veneer_Type            0
# Brick_Veneer_Area            0
# Exterior_Material            0
# Exterior_Condition           0
# Foundation_Type              0
# Basement_Height              0
# Basement_Condition           0
# Exposure_Level               0
# BsmtFinType1                 0
# ...

# %%
df.head()
# Out:
#   Building_Class Zoning_Class  Lot_Extent  Lot_Size Property_Shape  \
# 0             60          RLD        65.0      8450            Reg
# 1             20          RLD        80.0      9600            Reg
# 2             60          RLD        68.0     11250            IR1
# 3             70          RLD        60.0      9550            IR1
# 4             60          RLD        84.0     14260            IR1
#
#   Land_Outline Lot_Configuration Property_Slope Neighborhood Condition1  \
# 0          Lvl                 I             GS      CollgCr       Norm
# 1          Lvl              FR2P             GS      Veenker      Feedr
# 2          Lvl                 I             GS      CollgCr       Norm
# 3          Lvl                 C             GS      Crawfor       Norm
# 4          Lvl              FR2P             GS      NoRidge       Norm
#
#   Condition2 House_Type House_Design  Overall_Material  House_Condition  \
# ...

# %%
df.shape
# Out:
# (1459, 72)

# %%
continuous_feature.pop(-1)
# Out:
# 'Sale_Price'

# %% [markdown]
# # Removing outliers

# %%
# Removing outliers to make the model more robust
# From EDA we see that Living Area, Garage Area, Basement Area and Lot Area. Removing outliers from these. Other outliers will be handled 
# during power transform
def drop_outliers(x):
    list = []
    continuous_feature
    #outl_col = ['Grade_Living_Area','Garage_Area','Total_Basement_Area','Lot_Size','Lot_Extent']
    for col in continuous_feature:
        Q1 = x[col].quantile(.25)
        Q3 = x[col].quantile(.75)
        IQR = Q3-Q1
        x =  x[(x[col] >= (Q1-(1.5*IQR))) & (x[col] <= (Q3+(1.5*IQR)))] 
    return x  
df = drop_outliers(df)
df.shape
# Out:
# (905, 72)

# %%
df.head()
# Out:
#   Building_Class Zoning_Class  Lot_Extent  Lot_Size Property_Shape  \
# 1             20          RLD        80.0      9600            Reg
# 2             60          RLD        68.0     11250            IR1
# 3             70          RLD        60.0      9550            IR1
# 4             60          RLD        84.0     14260            IR1
# 5             50          RLD        85.0     14115            IR1
#
#   Land_Outline Lot_Configuration Property_Slope Neighborhood Condition1  \
# 1          Lvl              FR2P             GS      Veenker      Feedr
# 2          Lvl                 I             GS      CollgCr       Norm
# 3          Lvl                 C             GS      Crawfor       Norm
# 4          Lvl              FR2P             GS      NoRidge       Norm
# 5          Lvl                 I             GS      Mitchel       Norm
#
#   Condition2 House_Type House_Design  Overall_Material  House_Condition  \
# ...

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %% [markdown]
# # Categorical Features to Numbers

# %%
from sklearn.preprocessing import LabelEncoder

# process columns, apply LabelEncoder to categorical features
for c in categorical_features:
    lb = LabelEncoder() 
    lb.fit(list(df[c].values)) 
    df[c] = lb.transform(list(df[c].values))
data=df.copy()
# shape        
print('Shape all_data: {}'.format(df.shape))
# Out:
# Shape all_data: (905, 72)

# %%
df.head()
# Out:
#    Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Property_Shape  \
# 1               4             3        80.0      9600               3
# 2               9             3        68.0     11250               0
# 3              10             3        60.0      9550               0
# 4               9             3        84.0     14260               0
# 5               8             3        85.0     14115               0
#
#    Land_Outline  Lot_Configuration  Property_Slope  Neighborhood  Condition1  \
# 1             3                  2               0            22           1
# 2             3                  4               0             3           2
# 3             3                  0               0             4           2
# 4             3                  2               0            13           2
# 5             3                  4               0             9           2
#
#    Condition2  House_Type  House_Design  Overall_Material  House_Condition  \
# ...

# %% [markdown]
# # Feature_Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(df)
df_final=pd.DataFrame(scaled,columns=df.columns)
df_final.head()
# Out:
#    Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Property_Shape  \
# 0        0.285714          0.75    0.640000  0.505585             1.0
# 1        0.642857          0.75    0.480000  0.619363             0.0
# 2        0.714286          0.75    0.373333  0.502138             0.0
# 3        0.642857          0.75    0.693333  0.826920             0.0
# 4        0.571429          0.75    0.706667  0.816922             0.0
#
#    Land_Outline  Lot_Configuration  Property_Slope  Neighborhood  Condition1  \
# 0           1.0                0.5             0.0      1.000000       0.125
# 1           1.0                1.0             0.0      0.136364       0.250
# 2           1.0                0.0             0.0      0.181818       0.250
# 3           1.0                0.5             0.0      0.590909       0.250
# 4           1.0                1.0             0.0      0.409091       0.250
#
#    Condition2  House_Type  House_Design  Overall_Material  House_Condition  \
# ...

# %%
df_final.shape
# Out:
# (905, 72)

# %% [markdown]
# # Model_Building

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_final.drop('Sale_Price',axis=1)
y = df_final['Sale_Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
#RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=42)
rf=model.fit(X_train,y_train)
predictions=model.predict(X_test)
from sklearn.metrics import mean_absolute_error,mean_squared_error
MAE=mean_absolute_error(y_test,predictions)
MSE=mean_squared_error(y_test,predictions)
MAE,MSE
# Out:
# (0.03964837588640673, 0.0027681273581334036)

# %%
#here, Mean square error ad mean absulute error both are closer to zero,so our model is is fitted well

# %%
#Parameter tuning

# %%
l=[]
n_estmators=[20,50,100,200,70]
for e in n_estmators:
    model=RandomForestRegressor(n_estimators=e,random_state=42)
    rf=model.fit(X_train,y_train)
    predictions=model.predict(X_test)
    MSE=mean_squared_error(y_test,predictions)
    l.append(MSE)
print(l)
# Out:
# [0.0024412577206589132, 0.0021640901590367955, 0.0021912909928112714, 0.0021410305758634246, 0.0022234718204884813]

# %% [markdown]
# # Importing New data

# %%
# here I had imported test data and made prediction using above model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)


df2=pd.read_csv(r'F:edu_project/Property_Price_Test.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df2.head()

df2.shape

num_col = []
cat_col = []
for i in df2.columns:
    if df2[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
#print('There are', len(num_col) ,'numerical features in the dataset')
#print('There are', len(cat_col), 'categorical features in the dataset')

df2.isnull().any().sum()

#print('Percentage of Missing Values in each column is as follows:')
#print(round(df2.isnull().sum()/len(df2.index)*100,2).sort_values(ascending=False)[ round(df2.isnull().sum()/len(df2.index),2) > 0 ] )

df2 = df2.drop(['Lane_Type','Fireplace_Quality','Pool_Quality','Fence_Quality','Miscellaneous_Feature'],axis='columns')
df2.shape
year_feature = [feature for feature in num_col if 'Yr' in feature or 'Year' in feature]

num_col = []
cat_col = []
for i in df2.columns:
    if df2[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
#print('There are', len(num_col) ,'numerical features in the dataset')
#print('There are', len(cat_col), 'categorical features in the dataset')

discrete_feature=[feature for feature in num_col if len(df2[feature].unique())<26 and feature not in year_feature+['Id']]
#print("Discrete Variables Count: {}".format(len(discrete_feature)))

continuous_feature=[feature for feature in num_col if feature not in discrete_feature+year_feature+['Id']]
#print("Continuous feature Count {}".format(len(continuous_feature)))

categorical_features=[feature for feature in df2.columns if df2[feature].dtypes=='O']
len(categorical_features)

df2.shape

for feature in ['Construction_Year','Remodel_Year','Garage_Built_Year']:
       
    df2[feature]=df2['Year_Sold']-df2[feature]
    
df2.shape    
# Dropping ID Columns from dataset since it is useless in the prediction usecase
df2.drop('Id', axis=1, inplace=True)
df2.drop(['Road_Type', 'Utility_Type', 'Pool_Area'],axis=1,inplace=True)
df2.shape

df2[['Building_Class']] = df2[['Building_Class']].astype(str)
df2[['Month_Sold']] = df2[['Month_Sold']].astype(str)
df2[['Year_Sold']] = df2[['Year_Sold']].astype(str)

# Checking the number of numerical features and the number of categorical features
num_col = []
cat_col = []
for i in df2.columns:
    if df2[i].dtypes != 'O':
        num_col.append(i)
    else:
        cat_col.append(i)
#print('There are', len(num_col) ,'numerical features in the dataset')
#print('There are', len(cat_col), 'categorical features in the dataset')

for e in cat_col:
    df2[e]=df2[e].fillna(df2[e].mode()[0])
for e in num_col:
    df2[e]=df2[e].fillna(df2[e].median())
df2.isnull().sum().any()

def drop_outliers(x):
    list = []
    continuous_feature
    #outl_col = ['Grade_Living_Area','Garage_Area','Total_Basement_Area','Lot_Size','Lot_Extent']
    for col in continuous_feature:
        Q1 = x[col].quantile(.25)
        Q3 = x[col].quantile(.75)
        IQR = Q3-Q1
        x =  x[(x[col] >= (Q1-(1.5*IQR))) & (x[col] <= (Q3+(1.5*IQR)))] 
    return x  
df2 = drop_outliers(df2)
df2.shape
categorical_features=[feature for feature in df2.columns if df2[feature].dtype=='O']

from sklearn.preprocessing import LabelEncoder

# process columns, apply LabelEncoder to categorical features
for c in categorical_features:
    lb = LabelEncoder() 
    lb.fit(list(df2[c].values)) 
    df2[c] = lb.transform(list(df2[c].values))

# shape        
#print('Shape all_data: {}'.format(df2.shape))

#from sklearn.preprocessing import MinMaxScaler
# define min max scaler
#scaler = MinMaxScaler()
# transform data
#scaled = scaler.fit_transform(df2)
#df2_final=pd.DataFrame(scaled,columns=df2.columns)
#df2_final.head()
from sklearn.model_selection import train_test_split
X = data.drop('Sale_Price',axis=1)
y = data['Sale_Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=42)
rf=model.fit(X_train,y_train)
predictions=model.predict(X_test)
# shape        
#print('Shape all_data: {}'.format(df2.shape))

#from sklearn.preprocessing import MinMaxScaler
# define min max scaler
#scaler = MinMaxScaler()
# transform data
#scaled = scaler.fit_transform(df2)
#df2_final=pd.DataFrame(scaled,columns=df2.columns)
#df2_final.head()

# %% [markdown]
# # Predictions

# %%
output=model.predict(df2)
print(output)
# Out:
# [171623.4 182340.  180018.5 175238.  184568.  288451.2 262439.8 249421.3
#  209016.5 180370.7 168378.  172593.4 192600.  242318.  196063.1 177764.
#  246599.  192270.  166880.  201660.  184990.  168300.  160275.9 158400.
#  131171.3 151740.  117325.8 110430.  120810.  108860.  114730.4  88490.
#  226885.  140360.  163100.  119360.  132430.  148530.  134660.  160730.
#  125350.  165490.   77989.3 194750.  137340.4 134467.5 202591.7 111360.
#  186418.1 142020.  138170.  194890.  135400.  243118.  142750.  137670.
#  111451.6 102850.  186045.  208720.  208892.2  79280.  230983.5 197445.5
#  184948.2 167922.4 140530.  165298.5 149350.5 126110.  152350.5 120500.
#  186210.  244480.  240199.  259241.2 174043.4 178468.5 182075.  152870.5
#  185580.  181450.  203080.  228270.  155880.  159840.  136747.6 149500.
#  122750.  123940.  326579.  290949.3 342263.4 256582.8 176215.  179183.2
#  210090.  314448.8 189230.  168091.5 182780.  181438.  169296.9 174944.
# ...
